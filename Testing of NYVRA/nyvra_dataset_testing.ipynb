# %%
import pandas as pd

df = pd.read_csv("C:/Users/druth/Downloads/undated_dataset_NYVRA.csv")
df.head()
# Out:
# C:\Users\druth\AppData\Local\Temp\ipykernel_3504\1537757886.py:3: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/druth/Downloads/undated_dataset_NYVRA.csv")
#   District_Name        UnitName  FIR_YEAR  FIR_MONTH  Unnamed: 4  FIR_Day  \
# 0      Bagalkot  Guledagudda PS      2016         11         NaN        4
# 1      Bagalkot  Guledagudda PS      2016         11         NaN        5
# 2      Bagalkot  Guledagudda PS      2016         11         NaN        7
# 3      Bagalkot  Guledagudda PS      2016         11         NaN        7
# 4      Bagalkot  Guledagudda PS      2016         11         NaN        8
#
#       FIR Type      FIR_Stage      Complaint_Mode            CrimeGroup_Name  \
# 0  Non Heinous        Dis/Acq  Sue-moto by Police  KARNATAKA POLICE ACT 1963
# 1  Non Heinous     Compounded  Sue-moto by Police                       CrPC
# ...

# %%
df.shape
# Out:
# (1038576, 28)

# %%
df.columns
# Out:
# Index(['District_Name', 'UnitName', 'FIR_YEAR', 'FIR_MONTH', 'FIR_Day',
#        'FIR Type', 'FIR_Stage', 'Complaint_Mode', 'CrimeGroup_Name',
#        'CrimeHead_Name', 'Latitude', 'Longitude', 'ActSection', 'KGID',
#        'Internal_IO', 'Place of Offence', 'Distance from PS', 'Beat_Name',
#        'Village_Area_Name', 'Accused Count', 'Arrested Male',
#        'Arrested Female', 'Arrested Count\tNo.', 'Accused_ChargeSheeted Count',
#        'Conviction Count', 'Unit_ID'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# District_Name                      0
# UnitName                           0
# FIR_YEAR                           0
# FIR_MONTH                          0
# FIR_Day                            0
# FIR Type                           0
# FIR_Stage                          0
# Complaint_Mode                     0
# CrimeGroup_Name                    0
# CrimeHead_Name                     0
# Latitude                       69450
# Longitude                      69450
# ActSection                         0
# KGID                               0
# Internal_IO                        0
# Place of Offence                   0
# Distance from PS                   0
# Beat_Name                          0
# Village_Area_Name                  0
# Accused Count                      0
# Arrested Male                      0
# Arrested Female                    0
# Arrested Count\tNo.                0
# Accused_ChargeSheeted Count        0
# Conviction Count                   0
# ...

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# District_Name                  0
# UnitName                       0
# FIR_YEAR                       0
# FIR_MONTH                      0
# FIR_Day                        0
# FIR Type                       0
# FIR_Stage                      0
# Complaint_Mode                 0
# CrimeGroup_Name                0
# CrimeHead_Name                 0
# Latitude                       0
# Longitude                      0
# ActSection                     0
# KGID                           0
# Internal_IO                    0
# Place of Offence               0
# Distance from PS               0
# Beat_Name                      0
# Village_Area_Name              0
# Accused Count                  0
# Arrested Male                  0
# Arrested Female                0
# Arrested Count\tNo.            0
# Accused_ChargeSheeted Count    0
# Conviction Count               0
# Unit_ID                        0
# dtype: int64

# %%
df.dtypes
# Out:
# District_Name                   object
# UnitName                        object
# FIR_YEAR                         int64
# FIR_MONTH                        int64
# FIR_Day                          int64
# FIR Type                        object
# FIR_Stage                       object
# Complaint_Mode                  object
# CrimeGroup_Name                 object
# CrimeHead_Name                  object
# Latitude                       float64
# Longitude                      float64
# ActSection                      object
# KGID                            object
# Internal_IO                      int64
# Place of Offence                object
# Distance from PS                object
# Beat_Name                       object
# Village_Area_Name               object
# Accused Count                    int64
# Arrested Male                    int64
# Arrested Female                  int64
# Arrested Count\tNo.              int64
# Accused_ChargeSheeted Count      int64
# ...

# %%
df.duplicated().sum()
# Out:
# 27197

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df['FIR_MONTH'].between(1, 12).all()
# Out:
# True

# %%
df['FIR_Day'].between(1, 31).all()
# Out:
# True

# %%
(df['Arrested_Count'] <= df['Accused_Count']).all()
# Out:
# False

# %%
(df['Arrested_Count'] > df['Accused_Count']).sum()
# Out:
# 53035

# %%
df[df['Arrested_Count'] > df['Accused_Count']]
# Out:
#         District_Name        UnitName  FIR_YEAR  FIR_MONTH  FIR_Day  \
# 22           Bagalkot  Guledagudda PS      2017          1       20
# 23           Bagalkot  Guledagudda PS      2017          1       20
# 40           Bagalkot  Guledagudda PS      2017          2       24
# 41           Bagalkot  Guledagudda PS      2017          2       27
# 42           Bagalkot  Guledagudda PS      2017          2       27
# ...               ...             ...       ...        ...      ...
# 1038526    Kalaburagi        Sedam PS      2019          8       16
# 1038537    Kalaburagi        Sedam PS      2019          9        5
# 1038548    Kalaburagi        Sedam PS      2019          9       19
# 1038557    Kalaburagi        Sedam PS      2019         10        3
# 1038559    Kalaburagi        Sedam PS      2019         10        4
#
#             FIR_Type      FIR_Stage      Complaint_Mode  \
# 22       Non Heinous  Pending Trial  Sue-moto by Police
# ...

# %%
(df['Arrested_Count'] <= df['Accused_Count']).all()
# Out:
# True

# %%
df = df.rename(columns={
    'FIR_YEAR': 'year',
    'FIR_MONTH': 'month',
    'FIR_Day': 'day'
})

# %%
df['Date'] = pd.to_datetime(df[['year', 'month', 'day']])
df[['year','month','day','Date']].head()
# Out:
#    year  month  day       Date
# 0  2016     11    4 2016-11-04
# 1  2016     11    5 2016-11-05
# 2  2016     11    7 2016-11-07
# 3  2016     11    7 2016-11-07
# 4  2016     11    8 2016-11-08

# %%
df[['Latitude', 'Longitude']].describe()
# Out:
#             Latitude      Longitude
# count  888894.000000  888894.000000
# mean       13.838740      76.858560
# std         1.438931       0.965985
# min        11.666271      74.106156
# 25%        12.996545      76.124856
# 50%        13.022235      77.510184
# 75%        14.340942      77.567183
# max        18.385949      78.571536
